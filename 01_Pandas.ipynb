# %% [markdown]
# <a href="https://colab.research.google.com/github/manojmulammagari/data-analysis-python-practice/blob/main/01_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.Series([5,4,3,2,1],index=[1,2,3,4,5])
print(df)
# Out:
# 1    5
# 2    4
# 3    3
# 4    2
# 5    1
# dtype: int64

# %%
import pandas as pd
a=pd.DataFrame({"Name":['Manoj','Priya','Sudeer','vani'],'marks':[96,44,35,19]})
print(a)
a.index
# Out:
#      Name  marks
# 0   Manoj     96
# 1   Priya     44
# 2  Sudeer     35
# 3    vani     19
# RangeIndex(start=0, stop=4, step=1)

# %%
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
a.shape
# Out:
# (4, 2)

# %%
a.size
# Out:
# 8

# %%
a.columns
# Out:
# Index(['Name', 'marks'], dtype='object')

# %%
a.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1), Index(['Name', 'marks'], dtype='object')]

# %%
a.dtypes
# Out:
# Name     object
# marks     int64
# dtype: object

# %%
a.values
# Out:
# array([['Manoj', 96],
#        ['Priya', 44],
#        ['Sudeer', 35],
#        ['vani', 19]], dtype=object)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   marks   4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
a.describe()
# Out:
#           marks
# count   4.00000
# mean   48.50000
# std    33.31166
# min    19.00000
# 25%    31.00000
# 50%    39.50000
# 75%    57.00000
# max    96.00000

# %%
a.memory_usage()
# Out:
# Index    132
# Name      32
# marks     32
# dtype: int64

# %%
a.select_dtypes(include='number')
# Out:
#    marks
# 0     96
# 1     44
# 2     35
# 3     19

# %%
a[['Name','marks']]
# Out:
#      Name  marks
# 0   Manoj     96
# 1   Priya     44
# 2  Sudeer     35
# 3    vani     19

# %%
print(a)
# Out:
#      Name  marks
# 0   Manoj     96
# 1   Priya     44
# 2  Sudeer     35
# 3    vani     19

# %%
a.iloc[0:4,1]
# Out:
# 0    96
# 1    44
# 2    35
# 3    19
# Name: marks, dtype: int64

# %%
a.loc[0:3,['Name','marks']]
# Out:
#      Name  marks
# 0   Manoj     96
# 1   Priya     44
# 2  Sudeer     35
# 3    vani     19

# %%
b=pd.DataFrame({'Language':['Python','JAVA','C++',"HTML"],'Use':['MORE IMPORTANT','NORMAL',"DIfferent","WEB DEVELOP"]})
b
# Out:
#   Language             Use
# 0   Python  MORE IMPORTANT
# 1     JAVA          NORMAL
# 2      C++       DIfferent
# 3     HTML     WEB DEVELOP

# %%
b.shape,b.size,b.ndim
# Out:
# ((4, 2), 8, 2)

# %%
b.columns
# Out:
# Index(['Language', 'Use'], dtype='object')

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Language  4 non-null      object
#  1   Use       4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
b.memory_usage()
# Out:
# Index       132
# Language     32
# Use          32
# dtype: int64

# %%
b.select_dtypes(include='object')
# Out:
#   Language             Use
# 0   Python  MORE IMPORTANT
# 1     JAVA          NORMAL
# 2      C++       DIfferent
# 3     HTML     WEB DEVELOP

# %%
b['Language']
# Out:
# 0    Python
# 1      JAVA
# 2       C++
# 3      HTML
# Name: Language, dtype: object

# %%
b[['Language','Use']]
# Out:
#   Language             Use
# 0   Python  MORE IMPORTANT
# 1     JAVA          NORMAL
# 2      C++       DIfferent
# 3     HTML     WEB DEVELOP

# %%
b.loc[1:2,'Use']
# Out:
# 1       NORMAL
# 2    DIfferent
# Name: Use, dtype: object

# %%
b.describe()
# Out:
#        Language             Use
# count         4               4
# unique        4               4
# top      Python  MORE IMPORTANT
# freq          1               1
